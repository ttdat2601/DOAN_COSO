# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import pickle
import tensorflow as tf
from tensorflow.keras import layers, models


# Load train
train_data = np.load("C:/Users/Loc/Desktop/Do_An_Co_So/Do_An_Co_So/code/code_final/data_split/train_embeddings.npz")
X_train = train_data["features"]
y_train = train_data["labels"]

# Load test
test_data = np.load("C:/Users/Loc/Desktop/Do_An_Co_So/Do_An_Co_So/code/code_final/data_split//test_embeddings.npz")
X_test = test_data["features"]
y_test = test_data["labels"]

# Load label encoder đã lưu
with open("C:/Users/Loc/Desktop/Do_An_Co_So/Do_An_Co_So/code/code_final/label_encoder.pkl", "rb") as f:
    encoder = pickle.load(f)

# Chuyển đổi nhãn text sang số nguyên
y_train_enc = encoder.transform(y_train)
y_test_enc = encoder.transform(y_test)

# One-hot encode cho softmax
y_train_cat = to_categorical(y_train_enc)
y_test_cat = to_categorical(y_test_enc)

# %%
# Đưa vào mô hình DL 

# xác định giá trị đầu vào ( vecto embedding)
input_shape = X_train.shape[1:]  

# Cho đi qua hai lớp ẩn Dense với số lượng neuron lần lượt là 256 và 128 kèm theo Dropout để giảm overfitting, 
# cuối cùng là một lớp Dense sử dụng softmax để dự đoán xác suất các lớp (tương ứng với số người cần nhận diện).
model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(y_train_cat.shape[1], activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(
    X_train, y_train_cat,
    validation_data=(X_test, y_test_cat),
    epochs=30,
    batch_size=32
)

model.save("facenet.h5")
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.1363 - loss: 3.5141 - val_accuracy: 0.4251 - val_loss: 3.1530
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3932 - loss: 2.9782 - val_accuracy: 0.8073 - val_loss: 2.1254
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7266 - loss: 1.9408 - val_accuracy: 0.8930 - val_loss: 0.9353
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8462 - loss: 0.9899 - val_accuracy: 0.9174 - val_loss: 0.4177
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8739 - loss: 0.5260 - val_accuracy: 0.9266 - val_loss: 0.2644
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9109 - loss: 0.3389 - val_accuracy: 0.9235 - val_loss: 0.1913
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9325 - loss: 0.2668 - val_accuracy: 0.9144 - val_loss: 0.1744
# Epoch 8/30
# ...
